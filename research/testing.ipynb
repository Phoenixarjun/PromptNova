# %%
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
# print(GOOGLE_API_KEY)

# %%
# os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

from langchain.chat_models import init_chat_model


llm = init_chat_model(model="gemini-2.0-flash", model_provider="google_genai")


response = llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ### Zero-Shot Prompting

# %%
from langchain import PromptTemplate


zero_shot_prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

chain = zero_shot_prompt | llm

response = chain.invoke({"product": "colorful socks"})

# %%
print(response.content)
# Out:
# Okay, here are some name ideas for a colorful sock company, broken down by category:
#
# **Catchy & Playful:**
#
# *   Sock It To Me
# *   Happy Feet Threads
# *   Sole Mates
# *   Sock Hop
# *   Color My Soles
# *   Toe-tally Awesome Socks
# *   Sockadoodle
# *   Sock Mania
# *   The Sock Drawer
# *   Sock Star
# *   Sock Therapy
# *   Footloose Socks
# *   Socktopia
#
# **Descriptive & Evocative:**
#
# *   Chromatic Socks
# *   Kaleidoscope Toes
# *   Rainbow Threads
# *   Prism Socks
# *   Vivid Socks
# *   Saturated Soles
# *   Hue Haven
# *   Color Burst Socks
# *   Painted Toes
# *   Artful Ankles
# *   The Colorful Sock Co.
# *   Vibrant Footwear
#
# **Modern & Minimalist:**
#
# *   Solely Colors
# *   The Sock Edit
# *   Ankle Art
# *   Footnotes
# *   Socksmith
# *   Color Code Socks
# *   Thread Spectrum
# *   The Sock Lab
# *   Stride Colors
# *   Ankle Canvas
#
# **Names Emphasizing Quality/Comfort:**
#
# *   Cozy Colors
# *   Comfort & Color
# *   Deluxe Socks
# *   Premium Palette
# *   The Soft Sock
# *   Happy Feet Club
#
# **Location Specific (If applicable):**
#
# *   [Your City/Region] Socks
# *   [Local Landmark] Threads
#
# **Tips for Choosing:**
#
# *   **Target Audience:**  Who are you trying to reach?  A playful name might be great for kids, while a more sophisticated name might appeal to professionals.
# *   **Brand Personality:**  Do you want to be seen as fun, quirky, luxurious, or practical?
# *   **Availability:**  Check if the name is available as a website domain, social media handle, and trademark.
# *   **Memorability:**  Is the name easy to remember and pronounce?
# *   **Relevance:** Does the name clearly communicate what you sell?
#
# **To help me narrow down the best options for you, tell me:**
#
# *   **Who is your target audience?** (e.g., kids, adults, professionals, athletes, etc.)
# *   **What is the overall style/vibe of your socks?** (e.g., quirky, sophisticated, bold, minimalist, etc.)
# *   **Do you have a specific color palette or theme in mind?**
#
# Good luck!

# %% [markdown]
# ### Few Shot Prompting
